# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
x=[1,3,4,5 ,10]
y=[12,34,45,45, 50]

p_x=[1,3,4,5,7]
p_y=[12,34,45,45, 48]

# #  Js Data 
# j_x=[34,44,85]
# j_y=[1,2,3]

# %%
plt.xlabel('Ages')
plt.ylabel('Salary in (USD)')
# print(plt.style.available)
plt.style.use('fivethirtyeight')
# plt.plot(x, y , linewidth=8 , linestyle="dashdot", color="Green", 'g+')
plt.bar(x,y  ,label="All developers" ,linewidth=6)
# plt.bar(p_x, p_y  ,linewidth=2,  label="Python Developers")
plt.legend()
# plt.plot(j_x, j_y ,'bd-.' ,markersize=1 ,linewidth=2,  label="Js Developers")
